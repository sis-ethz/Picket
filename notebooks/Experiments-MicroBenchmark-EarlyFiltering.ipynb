# %%
import sys
sys.path.append('../')

from picket.prepare.dataPrepare import dataPrepareTrain
from picket.filter.filtersTrain import validate_early_filtering, printResEarlyFiltering

# %%
# dataset includes 'wine', 'adult', 'restaurant', 'marketing', 'titanic', 'HTRU2'
dataset = 'marketing'
# 'random', 'system' for all datasets, 'poison' for purely numerical datasets
noise_type = 'random'
# Can be 'lr', 'svm', 'nn' if noise_type is 'poison'
downstream_model = None

# %% [markdown]
# ## Train-test Split and Noise Injection

# %%
#dataPrepareTrain(dataset)

# %% [markdown]
# ## Outlier Detection at Training Time

# %%
validate_early_filtering(dataset, ntype=noise_type, modelname=downstream_model)
# Out:
# ############################################
# #                    0                     #
# ############################################
# Use Encoding: 1
# ----- Start warmup training... -----
# Epoch: 0
# CrossEntropy Loss: 1.321724 MSE Loss: 0.000000 Time elapsed: 17.944097 s
# Epoch: 1
# CrossEntropy Loss: 1.044028 MSE Loss: 0.000000 Time elapsed: 24.419003 s
# Epoch: 2
# CrossEntropy Loss: 0.953379 MSE Loss: 0.000000 Time elapsed: 24.893582 s
# Epoch: 3
# CrossEntropy Loss: 0.914854 MSE Loss: 0.000000 Time elapsed: 24.670953 s
# Epoch: 4
# CrossEntropy Loss: 0.899461 MSE Loss: 0.000000 Time elapsed: 25.724900 s
# Epoch: 5
# CrossEntropy Loss: 0.887310 MSE Loss: 0.000000 Time elapsed: 22.540800 s
# Epoch: 6
# CrossEntropy Loss: 0.883484 MSE Loss: 0.000000 Time elapsed: 26.526095 s
# Epoch: 7
# CrossEntropy Loss: 0.875278 MSE Loss: 0.000000 Time elapsed: 23.454184 s
# Epoch: 8
# CrossEntropy Loss: 0.870051 MSE Loss: 0.000000 Time elapsed: 23.884271 s
# Epoch: 9
# ...

# %%
printResEarlyFiltering(dataset, ntype=noise_type, modelname=downstream_model)
# Out:
# AUROC (filtering at early stage): 0.864994
# AUROC (filtering after convergence): 0.808247
